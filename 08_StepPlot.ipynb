# %% [markdown]
# # Step Plot

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,3,5,3,1]
plt.step(x,y,marker = "o",ms = 10, color = "r", mfc = "g", label = "python")
plt.title("Lakshay")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(loc = 2)
plt.grid()
plt.show()
