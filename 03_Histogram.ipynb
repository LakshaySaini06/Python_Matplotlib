# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10,60,(50))
print(x)
# Out:
# [57 32 47 33 29 13 44 54 43 31 33 14 11 27 10 15 19 17 55 56 17 36 12 11
#  59 49 18 51 53 45 24 55 35 34 22 46 50 56 23 26 26 30 55 29 37 12 31 48
#  14 42]

# %%
no = [57, 32, 47, 33, 29, 13, 44, 54, 43, 31,
      33, 14,11, 27, 10, 15, 19, 17, 55, 56, 
      17, 36, 12, 11, 59, 49,18, 51, 53, 45, 
      24, 55, 35, 34, 22, 46, 50, 56, 23, 26,
      26, 30,55, 29, 37, 12, 31, 48, 14, 42]

l = [10,20,30,40,50,60]
#plt.hist(no, color = "g",edgecolor = "r",range = (0,100),cumulative = -1,orientation = "horizontal",bottom =10,align = "left" ,bins = l,rwidth = 0.5, log = True)
plt.hist(no, color = "g",edgecolor = "r",histtype = "bar", label = "Lakshay")
plt.axvline(45, color = "r", label = "line")
plt.legend()
plt.title("Lakshay")
plt.xlabel("Numbers")
plt.ylabel("Occurances")
plt.grid()
plt.show()
