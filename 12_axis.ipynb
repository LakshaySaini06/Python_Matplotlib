# %% [markdown]
# # axis in matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,40,50,10,30]

plt.plot(x,y)
plt.xticks(x,labels = ["py","c","c++","java", "gd"])
plt.yticks(y)
plt.xlim(0,5)
plt.ylim(0,40)
plt.axis([0,6,0,50])
plt.show()
